# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold, train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from lightgbm import LGBMClassifier

from pycaret.classification import setup, evaluate_model, compare_models, plot_model#, add_metric

import optuna
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\Anaconda3\envs\pycaret_env\lib\site-packages\dask\dataframe\__init__.py in <module>
#      37     from .utils import assert_eq
# ---> 38     from .io.orc import read_orc
#      39
#
# ~\Anaconda3\envs\pycaret_env\lib\site-packages\dask\dataframe\io\orc\__init__.py in <module>
# ----> 1 from .core import read_orc, to_orc
#
# ~\Anaconda3\envs\pycaret_env\lib\site-packages\dask\dataframe\io\orc\core.py in <module>
#       8 from ....highlevelgraph import HighLevelGraph
# ----> 9 from ....layers import DataFrameIOLayer
#      10 from ....utils import apply
#
# ~\Anaconda3\envs\pycaret_env\lib\site-packages\dask\layers.py in <module>
#      13 from .base import tokenize
# ---> 14 from .blockwise import Blockwise, BlockwiseDep, BlockwiseDepDict, blockwise_token
#      15 from .core import flatten, keys_in_tasks
#
# ImportError: cannot import name 'BlockwiseDep' from 'dask.blockwise' (C:\Users\Anes3\Anaconda3\envs\pycaret_env\lib\site-packages\dask\blockwise.py)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9936\2512595877.py in <module>
#       8 from lightgbm import LGBMClassifier
#       9
# ---> 10 from pycaret.classification import setup, evaluate_model, compare_models, plot_model#, add_metric
#      11
#      12 import optuna
#
# ~\AppData\Roaming\Python\Python37\site-packages\pycaret\classification\__init__.py in <module>
# ----> 1 from pycaret.classification.functional import (
#       2     add_metric,
#       3     automl,
#       4     blend_models,
#       5     calibrate_model,
#
# ~\AppData\Roaming\Python\Python37\site-packages\pycaret\classification\functional.py in <module>
#       6 from joblib.memory import Memory
#       7
# ----> 8 from pycaret.classification.oop import ClassificationExperiment
#       9 from pycaret.internal.parallel.parallel_backend import ParallelBackend
#      10 from pycaret.loggers.base_logger import BaseLogger
#
# ~\AppData\Roaming\Python\Python37\site-packages\pycaret\classification\oop.py in <module>
#      14 from scipy.optimize import shgo
#      15
# ---> 16 from pycaret.containers.metrics import get_all_class_metric_containers
#      17 from pycaret.containers.models import get_all_class_model_containers
#      18 from pycaret.containers.models.classification import (
#
# ~\AppData\Roaming\Python\Python37\site-packages\pycaret\containers\metrics\__init__.py in <module>
#       4 from .clustering import get_all_metric_containers as get_all_clust_metric_containers
#       5 from .regression import get_all_metric_containers as get_all_reg_metric_containers
# ----> 6 from .time_series import get_all_metric_containers as get_all_ts_metric_containers
#
# ~\AppData\Roaming\Python\Python37\site-packages\pycaret\containers\metrics\time_series.py in <module>
#      15 from sklearn import metrics  # type: ignore
#      16 from sklearn.metrics._scorer import _BaseScorer  # type: ignore
# ---> 17 from sktime.performance_metrics.forecasting._functions import (  # type: ignore
#      18     mean_absolute_percentage_error,
#      19     mean_absolute_scaled_error,
#
# ~\AppData\Roaming\Python\Python37\site-packages\sktime\performance_metrics\forecasting\__init__.py in <module>
#      57 ]
#      58
# ---> 59 from sktime.performance_metrics.forecasting._classes import (
#      60     GeometricMeanAbsoluteError,
#      61     GeometricMeanRelativeAbsoluteError,
#
# ~\AppData\Roaming\Python\Python37\site-packages\sktime\performance_metrics\forecasting\_classes.py in <module>
#      15 from sklearn.utils import check_array
#      16
# ---> 17 from sktime.datatypes import VectorizedDF, check_is_scitype, convert_to
#      18 from sktime.performance_metrics.base import BaseMetric
#      19 from sktime.performance_metrics.forecasting._coerce import (
#
# ~\AppData\Roaming\Python\Python37\site-packages\sktime\datatypes\__init__.py in <module>
#       4 __author__ = ["fkiraly"]
#       5
# ----> 6 from sktime.datatypes._check import (
#       7     check_is_mtype,
#       8     check_is_scitype,
#
# ~\AppData\Roaming\Python\Python37\site-packages\sktime\datatypes\_check.py in <module>
#      31 from sktime.datatypes._alignment import check_dict_Alignment
#      32 from sktime.datatypes._common import _metadata_requested, _ret
# ---> 33 from sktime.datatypes._hierarchical import check_dict_Hierarchical
#      34 from sktime.datatypes._panel import check_dict_Panel
#      35 from sktime.datatypes._proba import check_dict_Proba
#
# ~\AppData\Roaming\Python\Python37\site-packages\sktime\datatypes\_hierarchical\__init__.py in <module>
#       6     convert_dict as convert_dict_Hierarchical,
#       7 )
# ----> 8 from sktime.datatypes._hierarchical._examples import (
#       9     example_dict as example_dict_Hierarchical,
#      10 )
#
# ~\AppData\Roaming\Python\Python37\site-packages\sktime\datatypes\_hierarchical\_examples.py in <module>
#     100
#     101     df_dask = convert_pandas_to_dask(
# --> 102         example_dict[("pd_multiindex_hier", "Hierarchical", 0)], npartitions=1
#     103     )
#     104
#
# ~\AppData\Roaming\Python\Python37\site-packages\sktime\datatypes\_adapter\dask_to_pd.py in convert_pandas_to_dask(obj, npartitions, chunksize, sort)
#     104         other columns and column names are identical to those of X
#     105     """
# --> 106     from dask.dataframe import from_pandas
#     107
#     108     def dask_mi_names(names):
#
# ~\Anaconda3\envs\pycaret_env\lib\site-packages\dask\dataframe\__init__.py in <module>
#      53         "  pip install dask[dataframe] --upgrade  # or pip install"
#      54     )
# ---> 55     raise ImportError(str(e) + "\n\n" + msg)
#
# ImportError: cannot import name 'BlockwiseDep' from 'dask.blockwise' (C:\Users\Anes3\Anaconda3\envs\pycaret_env\lib\site-packages\dask\blockwise.py)
#
# Dask dataframe requirements are not installed.
#
# Please either conda or pip install as follows:
#
#   conda install dask                     # either conda install
#   pip install dask[dataframe] --upgrade  # or pip install

# %% [markdown]
# # Load data

# %%
train = pd.read_csv('train.csv', index_col='id')
test = pd.read_csv('test.csv', index_col='id')

# %% [markdown]
# # Brief EDA

# %%
train.shape

# %%
test.shape

# %%
train.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1484\3346399198.py in <module>
# ----> 1 train.describe()
#
# NameError: name 'train' is not defined

# %%
train.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1484\642956413.py in <module>
# ----> 1 train.head()
#
# NameError: name 'train' is not defined

# %%
target = train.prognosis
X = train.drop('prognosis', axis=1)
target.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1484\4266518121.py in <module>
# ----> 1 target = train.prognosis
#       2 X = train.drop('prognosis', axis=1)
#       3 target.value_counts()
#
# NameError: name 'train' is not defined

# %% [markdown]
# # Target transformation

# %%
encoder = LabelEncoder()
y = encoder.fit_transform(target)

# %%
def apk(actual, predicted, k=10):
    """
    Computes the average precision at k.
    This function computes the average prescision at k between two lists of
    items.
    Parameters
    ----------
    actual : list
             A list of elements that are to be predicted (order doesn't matter)
    predicted : list
                A list of predicted elements (order does matter)
    k : int, optional
        The maximum number of predicted elements
    Returns
    -------
    score : double
            The average precision at k over the input lists
    """
    if not actual:
        return 0.0

    if len(predicted)>k:
        predicted = predicted[:k]

    score = 0.0
    num_hits = 0.0

    for i,p in enumerate(predicted):
        # first condition checks whether it is valid prediction
        # second condition checks if prediction is not repeated
        if p in actual and p not in predicted[:i]:
            num_hits += 1.0
            score += num_hits / (i+1.0)

    return score / min(len(actual), k)

def mapk(actual, predicted, k=10):
    """
    Computes the mean average precision at k.
    This function computes the mean average prescision at k between two lists
    of lists of items.
    Parameters
    ----------
    actual : list
             A list of lists of elements that are to be predicted 
             (order doesn't matter in the lists)
    predicted : list
                A list of lists of predicted elements
                (order matters in the lists)
    k : int, optional
        The maximum number of predicted elements
    Returns
    -------
    score : double
            The mean average precision at k over the input lists
    """
    return np.mean([apk(a,p,k) for a,p in zip(actual, predicted)])

# %%
_ = setup(data=train, target='prognosis')
# Out:
# <style type="text/css">
# #T_a890a_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a890a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a890a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a890a_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_a890a_row0_col1" class="data row0 col1" >2470</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a890a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a890a_row1_col1" class="data row1 col1" >prognosis</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a890a_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_a890a_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a890a_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_a890a_row3_col1" class="data row3 col1" >Chikungunya: 0, Dengue: 1, Japanese_encephalitis: 2, Lyme_disease: 3, Malaria: 4, Plague: 5, Rift_Valley_fever: 6, Tungiasis: 7, West_Nile_fever: 8, Yellow_Fever: 9, Zika: 10</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a890a_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_a890a_row4_col1" class="data row4 col1" >(707, 65)</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a890a_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_a890a_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a890a_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_a890a_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a890a_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_a890a_row7_col1" class="data row7 col1" >64</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a890a_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_a890a_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a890a_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_a890a_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a890a_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_a890a_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a890a_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_a890a_row11_col1" class="data row11 col1" >(494, 64)</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a890a_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_a890a_row12_col1" class="data row12 col1" >(213, 64)</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a890a_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_a890a_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a890a_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_a890a_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a890a_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_a890a_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a890a_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_a890a_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a890a_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_a890a_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a890a_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_a890a_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a890a_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_a890a_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a890a_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_a890a_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_a890a_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_a890a_row21_col1" class="data row21 col1" >15f5</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_a890a_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_a890a_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_a890a_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_a890a_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_a890a_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_a890a_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_a890a_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_a890a_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_a890a_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_a890a_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_a890a_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_a890a_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_a890a_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_a890a_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_a890a_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_a890a_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a890a_level0_row30" class="row_heading level0 row30" >30<

# %%
import numpy as np

# define a custom metric function
def custom_metric(y_true, y_pred):
    # your custom metric calculation here
    return np.mean(np.abs(y_true - y_pred))

# register the custom metric with PyCaret
add_metric('custom_metric', custom_metric)

# use the custom metric in PyCaret
from pycaret.regression import setup, compare_models

# set up the regression experiment
exp = setup(data, target='target')

# compare models using the custom metric
best_model = compare_models(metric='custom_metric')

# %%
best = compare_models(sort=mapk)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10388\3351929956.py in <module>
# ----> 1 best = compare_models(sort=mapk)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pycaret\classification.py in compare_models(include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, verbose, display, parallel)
#     837         probability_threshold=probability_threshold,
#     838         verbose=verbose,
# --> 839         display=display,
#     840     )
#     841
#
# ~\AppData\Roaming\Python\Python37\site-packages\pycaret\internal\tabular.py in compare_models(include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, verbose, display)
#    2018         if sort is None:
#    2019             raise ValueError(
# -> 2020                 f"Sort method not supported. See docstring for list of available parameters."
#    2021             )
#    2022
#
# ValueError: Sort method not supported. See docstring for list of available parameters.

# %%
y_pred = rf.predict_proba(test)
    
sorted_pred_idx = np.argsort(-y_pred, axis=1)[:,:3]
original_shape = sorted_pred_idx.shape
top3_pred = encoder.inverse_transform(sorted_pred_idx.reshape(-1,1))
top3_pred = top3_pred.reshape(original_shape)

# %%
test['prognosis'] = np.apply_along_axis(lambda x: np.array(' '.join(x), dtype="object"), 1, top3_pred)

# %% [markdown]
# # Submission

# %%
test.to_csv('submission_base_model.csv', columns=['prognosis'])
